# %%
import pandas as pd
# File name
CSV_PATH = "placement_predict_50k.csv"
# Read CSV file
df = pd.read_csv(CSV_PATH)
# 1. Display first 5 rows
print("FIRST 5 ROWS")
print(df.head())
# 2. Display dataset shape
print("\nDATASET SHAPE")
print(df.shape)
# 3. Display column names
print("\nCOLUMN NAMES")
print(df.columns)
# 4. Display data types
print("\nDATA TYPES")
print(df.dtypes)
# 5. Display basic information
print("\nDATASET INFORMATION")
df.info()
# 6. Display statistical summary
print("\nSTATISTICAL SUMMARY")
print(df.describe())
# 7. Check missing values
print("\nMISSING VALUES")
print(df.isnull().sum())
# 8. Check duplicate rows
print("\nDUPLICATE ROWS")
print(df.duplicated().sum())
# 9. Placement status distribution
print("\nPLACEMENT STATUS DISTRIBUTION")
print(df["PlacementStatus"].value_counts())
# 10. Placement status percentage
print("\nPLACEMENT STATUS PERCENTAGE")
print(df["PlacementStatus"].value_counts(normalize=True) * 100)
# Out:
# FIRST 5 ROWS
#    StudentID  Gender       City CollegeTier      Stream Specialisation Hostel  \
# 0          1  Female      Delhi       Tier3          IT    DataScience    Yes
# 1          2    Male    Chennai       Tier2         ECE             AI    Yes
# 2          3  Female  Hyderabad       Tier3         ECE     Networking     No
# 3          4  Female     Jaipur       Tier3         ECE       Embedded     No
# 4          5    Male  Ahmedabad       Tier3  Mechanical    DataScience     No
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Certifications  Publications  \
# 0               Yes       6.39       6.84  ...               1             0
# 1                No       5.95       6.74  ...               2             0
# 2                No       7.13       8.11  ...               2             1
# 3                No       9.37       9.97  ...               6             2
# 4                No       8.25       8.99  ...               4             2
#
# ...

# %% [markdown]
# ## Push to GitHub
#
# To push this notebook to GitHub, follow these steps. Make sure you have a GitHub Personal Access Token (PAT) with `repo` scope. You can generate one from your GitHub settings: `Settings` > `Developer settings` > `Personal access tokens` > `Tokens (classic)`.

# %%
# Install Git LFS if you plan to store large files (like models, datasets) in Git.
# This is optional, uncomment if you need it.
# !apt-get install git-lfs
# !git lfs install

# %% [markdown]
# ### 1. Authenticate with GitHub
#
# Colab provides a convenient way to securely store your GitHub Personal Access Token (PAT) using the `userdata` module. Replace `YOUR_GITHUB_TOKEN` with the name you use for your PAT in Colab's secrets manager.

# %%
from google.colab import userdata
import os

# IMPORTANT: Store your GitHub Personal Access Token in Colab secrets
# (click the '🔑' icon on the left panel, add a new secret named e.g., 'GITHUB_TOKEN')
# Then, uncomment and run the line below.
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN') # Replace 'GITHUB_TOKEN' with your secret name

# Configure Git credentials
# If you're having issues, you might need to try other methods, like using a credential helper.
# !git config --global credential.helper store
# !echo "https://oauth2:${GITHUB_TOKEN}@github.com" > ~/.git-credentials
# !git config --global credential.helper 'cache --timeout=3600' # Cache for 1 hour

# For HTTPS clone, you might set it like this, but the above is generally sufficient.
# os.environ['GH_TOKEN'] = GITHUB_TOKEN
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3475/2410604018.py in <cell line: 0>()
#       5 # (click the '🔑' icon on the left panel, add a new secret named e.g., 'GITHUB_TOKEN')
#       6 # Then, uncomment and run the line below.
# ----> 7 GITHUB_TOKEN = userdata.get('GITHUB_TOKEN') # Replace 'GITHUB_TOKEN' with your secret name
#       8
#       9 # Configure Git credentials
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GITHUB_TOKEN does not exist.

# %% [markdown]
# ### 2. Configure Git User
#
# Set your Git username and email. These will be associated with your commits.

# %%
# Replace with your GitHub email and username
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your GitHub Username"

# %% [markdown]
# ### 3. Initialize Git Repository and Push
#
# Now, you'll initialize a Git repository, add your notebook, commit it, and push it to GitHub.
#
# **Before running this cell:**
# 1.  **Create a new, empty repository on GitHub.** Do *not* initialize it with a `README.md`, `.gitignore`, or license.
# 2.  Copy the HTTPS clone URL (e.g., `https://github.com/your-username/your-repo-name.git`).
# 3.  Replace `YOUR_GITHUB_REPO_URL` with your repository's HTTPS URL.
#
# If you want to save the notebook, it's a good practice to save it before pushing, especially if you changed its name in Colab (e.g., `File` > `Save a copy in GitHub`). Colab automatically names the notebook `Untitled.ipynb` by default or based on its current name in Drive. You might want to rename it before committing.

# %%
# Define your repository URL and local directory
REPO_URL = "https://github.com/your-username/your-repo-name.git" # <--- REPLACE WITH YOUR REPO URL
REPO_DIR = "my_colab_project" # A local directory name for your project

# Create a directory for your project and change into it
# !mkdir -p {REPO_DIR}
# %cd {REPO_DIR}

# Initialize a new Git repository
# !git init

# Copy your Colab notebook into the repository directory
# The notebook you are currently running is typically in the root '/content/' directory.
# You might need to adjust the filename if you've renamed it.
# !cp /content/"My_Awesome_Notebook.ipynb" .

# Add all files (including the notebook) to the staging area
# !git add .

# Commit the changes
# !git commit -m "Initial commit: Add Colab notebook"

# Add the remote repository
# !git remote add origin {REPO_URL}

# Push to GitHub
# The --set-upstream option links your local branch to the remote branch
# You might be prompted for your GitHub username and password/PAT here if not already configured.
# !git push --set-upstream origin master
# Out:
# /content/my_colab_project
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/my_colab_project/.git/
# cp: cannot stat '/content/My_Awesome_Notebook.ipynb': No such file or directory
# On branch master
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/your-username/your-repo-name.git'
